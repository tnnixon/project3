# %%
import requests

from bs4 import BeautifulSoup

# %%
url = 'https://download.bls.gov/pub/time.series/la/'
r = requests.get(url, allow_redirects=True)
soup = BeautifulSoup(r.content, 'html.parser')

# %%
# print(soup.prettify())
tags = soup.find_all('a')
for t in tags:
     url = t['href']
     a = url.split('/')
     if len(a) == 5:
              b = a[4].split('.')
              if len(b) == 4:
                # print(b[2])
                 if int(b[2]) in range(7,60):
                         # download the file using the url
                            url2 = 'https://download.bls.gov'+url
                            print(url2)
                            r2 = requests.get(url2, allow_redirects=True)
                            open(a[4]+'.txt', 'wb').write(r2.content)
    #https://download.bls.gov/pub/time.series/la/la.data.10.Arkansas
# Out:
# https://download.bls.gov/pub/time.series/la/la.data.10.Arkansas
# https://download.bls.gov/pub/time.series/la/la.data.11.California
# https://download.bls.gov/pub/time.series/la/la.data.12.Colorado
# https://download.bls.gov/pub/time.series/la/la.data.13.Connecticut
# https://download.bls.gov/pub/time.series/la/la.data.14.Delaware
# https://download.bls.gov/pub/time.series/la/la.data.15.DC
# https://download.bls.gov/pub/time.series/la/la.data.16.Florida
# https://download.bls.gov/pub/time.series/la/la.data.17.Georgia
# https://download.bls.gov/pub/time.series/la/la.data.18.Hawaii
# https://download.bls.gov/pub/time.series/la/la.data.19.Idaho
# https://download.bls.gov/pub/time.series/la/la.data.20.Illinois
# https://download.bls.gov/pub/time.series/la/la.data.21.Indiana
# https://download.bls.gov/pub/time.series/la/la.data.22.Iowa
# https://download.bls.gov/pub/time.series/la/la.data.23.Kansas
# https://download.bls.gov/pub/time.series/la/la.data.24.Kentucky
# ...

# %%
import pandas as pd

# %%
#df = pd.read_csv('./data/la.data.7.Alabama.txt', sep="\t")
#df
websites = pd.read_csv("./data/la.data.7.Alabama.txt", sep="\t"
                      )


websites.to_csv('Alabama.csv', index = None)

websites
# Out:
#         series_id                       year period         value  \
# 0       LASST010000000000003            1976    M01           6.6
# 1       LASST010000000000003            1976    M02           6.6
# 2       LASST010000000000003            1976    M03           6.6
# 3       LASST010000000000003            1976    M04           6.5
# 4       LASST010000000000003            1976    M05           6.4
# ...                                ...   ...    ...           ...
# 234097  LAUST010000000000009            2021    M07     3898028.0
# 234098  LAUST010000000000009            2021    M08     3899874.0
# 234099  LAUST010000000000009            2021    M09     3901964.0
# 234100  LAUST010000000000009            2021    M10     3903838.0
# 234101  LAUST010000000000009            2021    M11     3905384.0
#
#        footnote_codes
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# ...

# %%
dd = pd.read_csv('./data/la.data.8.Alaska.txt', sep="\t")
dataframe1.to_csv('./data/la.data.7.Alabama.csv', 
                  index = None)
dd
# Out:
#        series_id                       year period         value  \
# 0      LASST020000000000003            1976    M01           7.1
# 1      LASST020000000000003            1976    M02           7.1
# 2      LASST020000000000003            1976    M03           7.0
# 3      LASST020000000000003            1976    M04           6.9
# 4      LASST020000000000003            1976    M05           6.9
# ...                               ...   ...    ...           ...
# 67073  LAUST020000000000009            2021    M07      544232.0
# 67074  LAUST020000000000009            2021    M08      544142.0
# 67075  LAUST020000000000009            2021    M09      544093.0
# 67076  LAUST020000000000009            2021    M10      544017.0
# 67077  LAUST020000000000009            2021    M11      543892.0
#
#       footnote_codes
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 67073            NaN
# ...

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir('./data') if isfile(join('./data', f))]
# onlyfiles

states_df = []
for file in onlyfiles:
    state = file.split('.')[3]
    df = pd.read_csv(f"./data/{file}", sep="\t")
    df['state'] = state
    states_df.append(df)

df_all = pd.concat(states_df)

df_all.to_csv('All_States_UnEmploy_Rates.csv', index = None)
df_all
# Out:
# C:\Users\14074\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         series_id                       year period        value  \
# 0       LASST050000000000003            1976    M01          7.3
# 1       LASST050000000000003            1976    M02          7.3
# 2       LASST050000000000003            1976    M03          7.3
# 3       LASST050000000000003            1976    M04          7.2
# 4       LASST050000000000003            1976    M05          7.1
# ...                                ...   ...    ...          ...
# 100309  LAUST040000000000009            2021    M07    5997462.0
# 100310  LAUST040000000000009            2021    M08    6009634.0
# 100311  LAUST040000000000009            2021    M09    6022140.0
# 100312  LAUST040000000000009            2021    M10    6034311.0
# ...
